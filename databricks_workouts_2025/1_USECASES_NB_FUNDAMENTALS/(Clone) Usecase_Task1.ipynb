# %% [markdown]
# # My First Use Case
# ## This use case is about to display my name with colour font
# My Name: <span style="background-color:yellow">Manikandan.S</span>

# %%
from IPython.display import display, HTML


html_text = "<span style='color:green; font-weight:bold;'>Manikandan.S</span>"
display(HTML(html_text))

# %% [markdown]
# ## **_Our Team Photo_**![](https://fpimages.withfloats.com/actual/6929d1ac956d0a744b5c9822.jpeg)

# %%
# %sql
CREATE VOLUME IF NOT EXISTS workspace.default.usage_metrics;

# %%
# %py
import requests

variable = requests.get("https://public.tableau.com/app/sample-data/mobile_os_usage.csv")
variable.raise_for_status()

dbutils.fs.put("/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv",variable.text,overwrite=True)
